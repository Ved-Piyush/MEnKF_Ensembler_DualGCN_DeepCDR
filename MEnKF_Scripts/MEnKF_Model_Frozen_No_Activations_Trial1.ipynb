# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import KFold
from sklearn.feature_selection import VarianceThreshold
import random
import pickle
from sklearn.preprocessing import StandardScaler
import os
import tensorflow as tf
from tqdm.notebook import tqdm
from scipy.stats import multivariate_normal as mvn
import matplotlib.pyplot as plt
from scipy.linalg import block_diag
import warnings
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

# %%
warnings.filterwarnings('ignore')

# %%
# len(weights_ann_1[0].ravel())

# %%
def get_targets_with_weights(batch_data, initial_ensembles, size_ens): 
    
    target_dim = 1
    
    # weights_ann_1 = ann.get_weights()
    
    # h1  = ann.layers[1].output.shape[-1]

    n_hidden_1 = len(weights_ann_1[0].ravel())
    
    hidden_weights_1 = initial_ensembles[:,:n_hidden_1].reshape( size_ens, batch_data.shape[1], h1)
    
    
    hidden_output_1 = np.einsum('ij,kjl->kil', batch_data, hidden_weights_1)

    
    hidden_layer_bias_1 = initial_ensembles[:,n_hidden_1:(n_hidden_1 + h1)].reshape(size_ens, 1,  h1)


    hidden_output_1 = hidden_output_1 + hidden_layer_bias_1

    n_pred_weights_1 = len(weights_ann_1[2].ravel())

    output_weights_1 = initial_ensembles[:,(n_hidden_1 + h1):(n_hidden_1 + h1 + n_pred_weights_1) ].reshape(size_ens, h1, target_dim)


    output_1 = np.einsum('ijk,ikl->ijl', hidden_output_1, output_weights_1)


    output_layer_bias_1 = initial_ensembles[:,(n_hidden_1 + h1 + n_pred_weights_1):(n_hidden_1 + h1 + n_pred_weights_1 + target_dim)].reshape(size_ens, 1, target_dim)


    final_output_1 = output_1 + output_layer_bias_1
    
    final_output_1 = final_output_1[:,:, 0]
    
    # print(final_output_1.shape, initial_ensembles.shape)
    
    stack = np.hstack((final_output_1, initial_ensembles))

    
    return final_output_1, stack

# %%
def ann(hidden = 32, input_shape = 256, output_shape = 1): 
    input_layer = tf.keras.layers.Input(shape = (input_shape))
    hidden_layer = tf.keras.layers.Dense(hidden)
    hidden_output = hidden_layer(input_layer)
    pred_layer = tf.keras.layers.Dense(output_shape, activation = "relu")
    pred_output = pred_layer(hidden_output)
#     pred_output = tf.keras.layers.Activation("softmax")(pred_output)
    model = tf.keras.models.Model(input_layer, pred_output)
    return model

# %%
def generate_initial_ensembles(num_weights, lambda1, size_ens):
    mean_vec = np.zeros((num_weights,))
    cov_matrix = lambda1*np.identity(num_weights)
    mvn_samp = mvn(mean_vec, cov_matrix)
    return mvn_samp.rvs(size_ens)

# %%
def expit(x):
    """Compute softmax values for each sets of scores in x."""
#     e_x = np.exp(x - np.max(x))
    return 1 / (1 + np.exp(-x))

# %%
samp_ann =  ann(hidden = 16, input_shape = 32, output_shape = 1)

# %%
weights_ann_1 = samp_ann.get_weights()

# %%
h1  = samp_ann.layers[1].output.shape[-1]

# %%
h1
# Out:
# 16

# %%
samp_ann.count_params()
# Out:
# 545

# %%
hidden_neurons = h1

# %%
samp_ann_params = samp_ann.count_params()

# %%
def get_initial_X_t(data1, data2, data3, data4, size_ens, var_weights = 1.0, var_weight_weights = 4.0, var_L = 1.0, var_D = 1.0):
    # samp_ann =  ann(hidden = hidden_neurons, input_shape = 32, output_shape = 1)
    
    initial_ensembles1 = generate_initial_ensembles(samp_ann_params, var_weights, size_ens)
    data1_out1, data1_stack1 = get_targets_with_weights(data1, initial_ensembles1, size_ens = size_ens)
    
    initial_ensembles2 = generate_initial_ensembles(samp_ann_params, var_weights, size_ens)
    data1_out2, data1_stack2 = get_targets_with_weights(data2, initial_ensembles2, size_ens = size_ens)
    
    initial_ensembles3 = generate_initial_ensembles(samp_ann_params, var_weights, size_ens)
    data2_out1, data2_stack1 = get_targets_with_weights(data3, initial_ensembles3, size_ens = size_ens)
    
    initial_ensembles4 = generate_initial_ensembles(samp_ann_params, var_weights, size_ens)
    data2_out2, data2_stack2 = get_targets_with_weights(data4, initial_ensembles4, size_ens = size_ens)   
    
    X_t = np.concatenate((np.expand_dims(data1_stack1, -1), np.expand_dims(data1_stack2, -1), 
                         np.expand_dims(data2_stack1, -1), np.expand_dims(data2_stack2, -1)), axis = -1)
    
    initial_ensembles_for_weights = generate_initial_ensembles(4, var_weight_weights, size_ens)
    initial_ensembles_for_weights = np.expand_dims(initial_ensembles_for_weights,1)
    
    # initial_ensembles_for_L = generate_initial_ensembles(4, var_L, size_ens)
    # initial_ensembles_for_L = np.expand_dims(initial_ensembles_for_L,1)    
    
    initial_ensembles_for_D1 = generate_initial_ensembles(1, var_D, size_ens).reshape(-1,1)
    # initial_ensembles_for_D2 = generate_initial_ensembles(1, var_D, size_ens).reshape(-1,1)
    
    initial_ensembles_for_D1_zero = np.zeros((size_ens,1,1)).reshape(-1,1)
    initial_ensembles_for_D2_zero = np.zeros((size_ens,1,1)).reshape(-1,1)
    
    initial_ensembles_for_D3_zero = np.zeros((size_ens,1,1)).reshape(-1,1)
    
    initial_ensembles_for_D = np.concatenate((np.expand_dims(initial_ensembles_for_D1,1),
                                                       np.expand_dims(initial_ensembles_for_D1_zero,1), 
                                                      np.expand_dims(initial_ensembles_for_D2_zero,1),
                                                       np.expand_dims(initial_ensembles_for_D3_zero,1)), axis = 2)
    
    # print(X_t.shape, initial_ensembles_for_weights.shape)
    
    X_t = np.concatenate((X_t, initial_ensembles_for_weights, initial_ensembles_for_D), axis = 1)
    
    initial_ensembles = np.hstack((initial_ensembles1, initial_ensembles2, initial_ensembles3, initial_ensembles4))
    
    return X_t, initial_ensembles, initial_ensembles_for_weights[:,0,:], initial_ensembles_for_D[:,0,:]

# %%
def get_weighted_targets_with_weights(batch_data, initial_ensembles, size_ens, weights): 
    
    target_dim = 1
    

    n_hidden_1 = len(weights_ann_1[0].ravel())
    
    hidden_weights_1 = initial_ensembles[:,:n_hidden_1].reshape( size_ens, batch_data.shape[1], h1)
    
    
    hidden_output_1 = np.einsum('ij,kjl->kil', batch_data, hidden_weights_1)

    
    hidden_layer_bias_1 = initial_ensembles[:,n_hidden_1:(n_hidden_1 + h1)].reshape(size_ens, 1,  h1)


    hidden_output_1 = hidden_output_1 + hidden_layer_bias_1

    n_pred_weights_1 = len(weights_ann_1[2].ravel())

    output_weights_1 = initial_ensembles[:,(n_hidden_1 + h1):(n_hidden_1 + h1 + n_pred_weights_1) ].reshape(size_ens, h1, target_dim)


    output_1 = np.einsum('ijk,ikl->ijl', hidden_output_1, output_weights_1)


    output_layer_bias_1 = initial_ensembles[:,(n_hidden_1 + h1 + n_pred_weights_1):(n_hidden_1 + h1 + n_pred_weights_1 + target_dim)].reshape(size_ens, 1, target_dim)


    final_output_1 = output_1 + output_layer_bias_1
    
    final_output_1 = final_output_1[:,:, 0]
    
    final_output_1 = final_output_1*weights
    
    # print(final_output_1.shape, initial_ensembles.shape)
    
    stack = np.hstack((final_output_1, initial_ensembles))

    
    return final_output_1, stack

# %%
from scipy.stats import beta

# %%
fudging_beta = beta(1,9)

# %%
def forward_operation(data1, data2, data3, data4, combined_ensembles , size_ens, fudging_beta):
    # samp_ann =  ann(hidden = hidden_neurons, input_shape = 32, output_shape = 1)
    params = samp_ann_params
    initial_ensembles1 = combined_ensembles[:, :params]
    initial_ensembles2 = combined_ensembles[:, params:(2*params)]
    initial_ensembles3 = combined_ensembles[:, (2*params):(3*params)]
    initial_ensembles4 = combined_ensembles[:, (3*params):(4*params)]

    
    initial_ensembles_for_weights = combined_ensembles[:, (4*params):(4*params + 4)]
    
    # initial_ensembles_for_L = combined_ensembles[:, (4*params + 4):(4*params + 4 + 4)]
    
    initial_ensembles_for_D = combined_ensembles[:,(4*params + 4):(4*params + 4 + 4 )]
    
    
    softmax_weights = tf.math.softmax(initial_ensembles_for_weights).numpy()
    
    # +  fudging_beta.rvs(size_ens).reshape(-1,1)
    
    model_1 = softmax_weights[:, 0].reshape(-1,1) 
    
    # model_1 = np.min(model_1 -fudging_factor)
    
    model_2 = softmax_weights[:, 1].reshape(-1,1) 
    
    model_3 = softmax_weights[:, 2].reshape(-1,1) 
    
    model_4 = softmax_weights[:, 3].reshape(-1,1)
    
    sum_weights = model_1 + model_2 + model_3 + model_4
    
    
    # model_1_plus_model_2 = model_1 + model_2
    
    model_1 = model_1/sum_weights
    
    model_2 = model_2/sum_weights
    
    model_3 = model_3/sum_weights
    
    model_4 = model_4/sum_weights
    
    
    # print(np.mean(model_1 + model_2))
    
    data1_out1, data1_stack1 = get_weighted_targets_with_weights(data1, initial_ensembles1, size_ens = size_ens,
                                                                  weights=model_1)
    
    data1_out2, data1_stack2 = get_weighted_targets_with_weights(data2, initial_ensembles2, size_ens = size_ens,
                                                                weights=model_2)
    
    data2_out1, data2_stack1 = get_weighted_targets_with_weights(data3, initial_ensembles3, size_ens = size_ens,
                                                                 weights=model_3)
    
    data2_out2, data2_stack2 = get_weighted_targets_with_weights(data4, initial_ensembles4, size_ens = size_ens,
                                                                  weights=model_4)   
    
    X_t = np.concatenate((np.expand_dims(data1_stack1, -1), np.expand_dims(data1_stack2, -1), 
                         np.expand_dims(data2_stack1, -1), np.expand_dims(data2_stack2, -1)), axis = -1)
    
    initial_ensembles = np.hstack((initial_ensembles1, initial_ensembles2, initial_ensembles3, initial_ensembles4, 
                        initial_ensembles_for_weights, initial_ensembles_for_D))
    
    # print(X_t.shape)
    
    initial_ensembles_for_weights = np.expand_dims(initial_ensembles_for_weights,1)
    
    # initial_ensembles_for_L = np.expand_dims(initial_ensembles_for_L,1)
    
    initial_ensembles_for_D = np.expand_dims(initial_ensembles_for_D,1)
    
    # print(initial_ensembles_for_weights.shape)
    
    X_t = np.concatenate((X_t, initial_ensembles_for_weights, initial_ensembles_for_D), axis = 1)
    
    final_output = data1_out1 + data1_out2 + data2_out1 + data2_out2
    
    # weighted_psa = data1_out2 + data2_out2
    
    return X_t, initial_ensembles,final_output, model_1, model_2, model_3, model_4

# %%
def forward_operation_test(data1, data2, data3, data4, combined_ensembles , size_ens):
    # samp_ann =  ann(hidden = hidden_neurons, input_shape = 32, output_shape = 1)
    params = samp_ann_params
    initial_ensembles1 = combined_ensembles[:, :params]
    initial_ensembles2 = combined_ensembles[:, params:(2*params)]
    initial_ensembles3 = combined_ensembles[:, (2*params):(3*params)]
    initial_ensembles4 = combined_ensembles[:, (3*params):(4*params)]

    
    initial_ensembles_for_weights = combined_ensembles[:, (4*params):(4*params + 4)]
    
    # initial_ensembles_for_L = combined_ensembles[:, (4*params + 4):(4*params + 4 + 4)]
    
    initial_ensembles_for_D = combined_ensembles[:,(4*params + 4):(4*params + 4 + 4)]
    
    
    softmax_weights = tf.math.softmax(initial_ensembles_for_weights).numpy()
    
    model_1 = softmax_weights[:, :1].reshape(-1,1)
    
    # model_1 = np.min(model_1 -fudging_factor)
    
    model_2 = softmax_weights[:, 1:2].reshape(-1,1) 
    
    model_3 = softmax_weights[:, 2:3].reshape(-1,1) 
    
    model_4 = softmax_weights[:, 3:4].reshape(-1,1)
    
    sum_weights = model_1 + model_2 + model_3 + model_4
    
    
    # model_1_plus_model_2 = model_1 + model_2
    
    model_1 = model_1/sum_weights
    
    model_2 = model_2/sum_weights
    
    model_3 = model_3/sum_weights
    
    model_4 = model_4/sum_weights
    
    data1_out1, data1_stack1 = get_weighted_targets_with_weights(data1, initial_ensembles1, size_ens = size_ens,
                                                                  weights=model_1)
    
    data1_out2, data1_stack2 = get_weighted_targets_with_weights(data2, initial_ensembles2, size_ens = size_ens,
                                                                weights=model_2)
    
    data2_out1, data2_stack1 = get_weighted_targets_with_weights(data3, initial_ensembles3, size_ens = size_ens,
                                                                 weights=model_3)
    
    data2_out2, data2_stack2 = get_weighted_targets_with_weights(data4, initial_ensembles4, size_ens = size_ens,
                                                                  weights=model_4)   
    
    X_t = np.concatenate((np.expand_dims(data1_stack1, -1), np.expand_dims(data1_stack2, -1), 
                         np.expand_dims(data2_stack1, -1), np.expand_dims(data2_stack2, -1)), axis = -1)
    
    initial_ensembles = np.hstack((initial_ensembles1, initial_ensembles2, initial_ensembles3, initial_ensembles4, 
                        initial_ensembles_for_weights, initial_ensembles_for_D))
    
    # print(X_t.shape)
    
    initial_ensembles_for_weights = np.expand_dims(initial_ensembles_for_weights,1)
    
    # initial_ensembles_for_L = np.expand_dims(initial_ensembles_for_L,1)
    
    initial_ensembles_for_D = np.expand_dims(initial_ensembles_for_D,1)
    
    # print(initial_ensembles_for_weights.shape)
    
    X_t = np.concatenate((X_t, initial_ensembles_for_weights, initial_ensembles_for_D), axis = 1)
    
    final_output = data1_out1 + data1_out2 + data2_out1 + data2_out2
    
    return X_t, initial_ensembles, final_output, model_1, model_2, model_3, model_4

# %%
samp_ann.count_params()
# Out:
# 545

# %%
total_weights = 4*(samp_ann.count_params() + 1 + 1)

# %%
# 4*(samp_ann.count_params()) + 1 + 1

# %%
# total_weights

# %%
reduction = 10

# %%
size_ens = total_weights//reduction

# %%
size_ens
# Out:
# 218

# %%
G_t = [[1, 1, 1, 1]]
G_t = np.array(G_t).T

# %%
G_t.shape
# Out:
# (4, 1)

# %%
def get_predictions(data1, data2, data3, data4, initial_ensembles, fudging_beta  =fudging_beta): 
    _,_, weighted_alogp, w1, w2, w3, w4 = forward_operation(data1, data2, data3, data4, initial_ensembles, size_ens = size_ens, fudging_beta = fudging_beta)
    return weighted_alogp, w1, w2, w3, w4

# %%
def get_predictions_test(data1, data2, data3, data4, initial_ensembles): 
    _,_, weighted_alogp, w1, w2, w3, w4 = forward_operation_test(data1, data2, data3, data4, initial_ensembles, size_ens = size_ens)
    return weighted_alogp, w1, w2, w3, w4

# %%
def calculate_mu_bar_G_bar(data1, data2, data3, data4, initial_ensembles, fudging_beta):
    H_t = np.hstack((np.identity(data1.shape[0]), np.zeros((data1.shape[0], samp_ann_params + 1  + 1))))
    mu_bar = initial_ensembles.mean(0)
    X_t, _,_, _, _, _, _ = forward_operation(data1, data2, data3, data4, initial_ensembles, size_ens = size_ens, fudging_beta = fudging_beta)
    X_t = X_t.transpose((0,2,1))
    X_t = X_t.reshape(X_t.shape[0], X_t.shape[1]*X_t.shape[2])
    script_H_t = np.kron(G_t.T, H_t)
    G_u = (script_H_t@X_t.T)
    G_u = G_u.T
    G_bar = (G_u.mean(0)).ravel()
    return mu_bar.reshape(-1,1), G_bar.reshape(-1,1), G_u

# %%
def calculate_C_u(initial_ensembles, mu_bar, G_bar, G_u): 
    u_j_minus_u_bar = initial_ensembles - mu_bar.reshape(1,-1)
    G_u_minus_G_bar = G_u -  G_bar.reshape(1,-1)
    c = np.zeros((total_weights, G_bar.shape[0]))
    for i in range(0, size_ens): 
        c += np.kron(u_j_minus_u_bar[i, :].T.reshape(-1,1), G_u_minus_G_bar[i,:].reshape(-1,1).T)
    return c/size_ens, G_u_minus_G_bar

# %%
def calculate_D_u( G_bar, G_u): 
    G_u_minus_G_bar = G_u -  G_bar.reshape(1,-1)
    d = np.zeros((G_bar.shape[0], G_bar.shape[0]))
    for i in range(0, size_ens): 
        d += np.kron(G_u_minus_G_bar[i,:].T.reshape(-1,1), G_u_minus_G_bar[i,:].reshape(-1,1).T)
    return d/size_ens

# %%
def get_updated_ensemble(data1, data2, data3, data4, initial_ensembles, y_train, size_ens = size_ens, inflation_factor = 1.0, fudging_beta = fudging_beta, 
                        fudging_var = None):
    mu_bar, G_bar, G_u = calculate_mu_bar_G_bar(data1, data2, data3, data4, initial_ensembles, fudging_beta)
    C, G_u_minus_G_bar = calculate_C_u(initial_ensembles, mu_bar, G_bar, G_u)
    D = calculate_D_u( G_bar, G_u)
    _, R_t = create_cov(data1.shape[0],initial_ensembles)
    inflation = np.identity(R_t.shape[0])*inflation_factor
    D_plus_cov = D + (R_t *inflation_factor)
    D_plus_cov_inv = np.linalg.inv(D_plus_cov)
    mid_quant = C@D_plus_cov_inv
    noise_vec_mean = np.zeros((R_t.shape[0], ))
    noise_mvn = mvn(noise_vec_mean, R_t)
    fudging = noise_mvn.rvs(size_ens)
    interim = (y_train.T.flatten().reshape(1,-1) + fudging)
    right_quant = interim - G_u
    mid_times_right = mid_quant@right_quant.T
    updated_ensemble = (initial_ensembles + mid_times_right.T)
    if fudging_var is not None: 
        mean_vec = np.zeros((updated_ensemble.shape[1],))
        cov_mat = np.identity(updated_ensemble.shape[1])*fudging_var
        fudging_for_updated_ensembles = mvn(mean_vec, cov_mat)
        fudging_for_updated_ensembles_vec = fudging_for_updated_ensembles.rvs(size_ens)
        updated_ensemble = updated_ensemble + fudging_for_updated_ensembles_vec
    return updated_ensemble

# %%
target_dim = 1

# %%
lambda_D = 1

# %%
from joblib import Parallel, delayed

# %%
def create_cov(shape, initial_ensembles):
    cov_part = initial_ensembles[:, -4:-3]
    cov_part = cov_part.mean(0)
    variances1 = tf.math.softplus(cov_part).numpy()
    n = shape
    return variances1, np.identity(n)*variances1

# %%
# idx = 1

# %%
with open("..//Data//gcn_cdr_train_pca.pickle", "rb") as f: 
    catch_train = pickle.load(f)

# %%
with open("..//Data//gcn_cdr_test_pca.pickle", "rb") as f: 
    catch_test = pickle.load(f)

# %%
import random

# %%
def prepare_data_train(catch_train, size): 
    idxes = random.sample(range(0, catch_train[0].shape[0]), k = size)
    idxes = list(idxes)
    data1, data2, data3, data4 = catch_train[0][idxes,:], catch_train[1][idxes,:], catch_train[2][idxes,:], catch_train[3][idxes,:]
    
    y_train = catch_train[-1][idxes].reshape(-1,1)
    
    return data1, data2, data3, data4, y_train

# %%
def prepare_data_test( catch_test, size): 
    idxes = random.sample(range(0, catch_test[0].shape[0]), k = size)
    idxes = list(idxes)
    data1, data2, data3, data4 = catch_test[0][idxes,:], catch_test[1][idxes,:], catch_test[2][idxes,:], catch_test[3][idxes,:]
    y_train = catch_test[-1][idxes].reshape(-1,1)
    return data1, data2, data3, data4, y_train

# %%
# data1_train, data2_train, data3_train, data4_train, y_train =  prepare_data_train(catch_train, size = 2500)

# %%
# data1_test, data2_test, data3_test, data4_test, y_test =  prepare_data_test(catch_test, size = 1000)

# %%
from scipy.stats import pearsonr

# %%
def get_results(idx, var_weights = 1.0, var_weight_weights = 4.0, var_D = 1, inflation_factor = 1.6, fudging_beta = beta(1,19), 
               fudging_var = 1e-3, epochs = 30):
    
    # smiles_feats_train, rdkit_feats_train, smiles_feats_valid, rdkit_feats_valid, y_train, y_train_actual, y_valid, y_valid_actual, initial_ensembles  = prepare_data(idx, var_weights = var_weights, var_weight_weights =var_weight_weights, var_L = var_L, var_D = var_D)
    
    
    data1_train, data2_train, data3_train, data4_train, y_train =  prepare_data_train(catch_train, size = 2500)
    
    data1_test, data2_test, data3_test, data4_test, y_test =  prepare_data_test(catch_test, size = 1000)
    
    X_t, initial_ensembles, initial_ensembles_for_weights, initial_ensembles_for_D = get_initial_X_t(data1_train, data2_train, data3_train, data4_train,
                                                                                                 size_ens = size_ens, var_weights = var_weights,
                                                                                                var_weight_weights = var_weight_weights, var_D = var_D)
    
    initial_ensembles = np.hstack((initial_ensembles, initial_ensembles_for_weights, initial_ensembles_for_D))
    
    best_rmse_train = 100000
    
    for i in range(0,epochs):
        print("epoch number is " +str(i))

        initial_ensembles = get_updated_ensemble(data1_train, data2_train, data3_train, data4_train, initial_ensembles, y_train, size_ens = size_ens,
                                                 inflation_factor = inflation_factor, fudging_beta = fudging_beta, fudging_var = fudging_var)
        
        G_u_train, w1, w2, w3, w4 = get_predictions(data1_train, data2_train, data3_train, data4_train, initial_ensembles, fudging_beta)
    
        li_train = np.percentile(G_u_train, axis = 0, q = (2.5, 97.5))[0,:].reshape(-1,1)    
        ui_train = np.percentile(G_u_train, axis = 0, q = (2.5, 97.5))[1,:].reshape(-1,1)  
    
        width_train = ui_train - li_train
        avg_width_train = width_train.mean(0)[0]
    
        ind_train = (y_train >= li_train) & (y_train <= ui_train)
        coverage_train= ind_train.mean(0)[0]
    
        averaged_targets_train = G_u_train.mean(0).reshape(-1,1)
        rmse_train = np.sqrt(((y_train -averaged_targets_train)**2).mean(0))[0]
        
        pearsonr_train = pearsonr(averaged_targets_train.reshape(averaged_targets_train.shape[0],), 
                                 y_train.reshape(y_train.shape[0],))
        
        r_train = pearsonr_train.statistic
    
        G_u_test, _, _, _, _ = get_predictions_test(data1_test, data2_test, data3_test, data4_test, initial_ensembles)
    

    
        li_test = np.percentile(G_u_test, axis = 0, q = (2.5, 97.5))[0,:].reshape(-1,1)     
        ui_test = np.percentile(G_u_test, axis = 0, q = (2.5, 97.5))[1,:].reshape(-1,1)   
    
        width_test = ui_test - li_test
        avg_width_test = width_test.mean(0)[0]
    
        ind_test = (y_test >= li_test) & (y_test <= ui_test)
        coverage_test= ind_test.mean(0)[0]
    
        averaged_targets_test = G_u_test.mean(0).reshape(-1,1)
        rmse_test = np.sqrt(((y_test -averaged_targets_test)**2).mean(0))[0]  
        
        pearsonr_test = pearsonr(averaged_targets_test.reshape(averaged_targets_test.shape[0],), 
                                 y_test.reshape(y_test.shape[0],))
        
        r_test = pearsonr_test.statistic

        print("Training Coverage, Widths, RMSE, and Pearson R")
        print(coverage_train, avg_width_train, rmse_train, r_train)
        print("Testing Coverage, Widths, RMSE, and Pearson R")
        print(coverage_test, avg_width_test, rmse_test, r_test)
        # print(w1.mean(), w1.std())

        if (rmse_train < best_rmse_train): 
            best_rmse_train = rmse_train
            # print("went here")
            best_train_width_mean = avg_width_train.mean()
            best_train_width = avg_width_train
            # best_smiles_weight = w1.mean()
            best_coverage_train = coverage_train
            best_rmse_train = rmse_train
            best_pearson_r = r_test
            best_test_width = avg_width_test

            best_coverage_test = coverage_test    
            best_rmse_test = rmse_test
            patience = 0
            best_ensembles = initial_ensembles
            
        else:
            patience = patience + 1
            
        print("Patience is")
        print(patience)
        print('\n')
        
        if (patience > threshold) | (i == (epochs-1)):
            
            # print()
            # print(best_train_width.tolist(), best_coverage_train.tolist(), best_rmse_train.tolist(), best_test_width.tolist(), best_coverage_test.tolist(), best_rmse_test.tolist(), best_smiles_weight, flush = True)
            # print("done for fold" + str(idx), flush = True)
            print("train_coverage" + str(best_coverage_train), flush = True)
            print("test_coverage" + str(best_coverage_test), flush = True)
            print("train_width" + str(best_train_width), flush = True)
            print("test_width" + str(best_test_width), flush = True)
            print("pearson" + str(best_pearson_r), flush = True)
            print("rmse_train" + str(best_rmse_train), flush = True)
            print("rmse_test" + str(best_rmse_test), flush = True)
            # print("smiles_weight_ci" + str([best_li_smiles_weight, best_ui_smiles_weight]), flush = True)
            
            return [best_train_width, best_coverage_train, best_rmse_train, best_test_width, best_coverage_test, best_rmse_test, best_pearson_r, best_ensembles, [data1_test, data2_test, data3_test, data4_test, y_test]]

# %%
threshold = 10

# %%
# best_train_width, best_coverage_train, best_rmse_train, best_test_width, best_coverage_test, best_rmse_test, best_pearson_r, best_ensembles

# %%
# %%time
best_train_width, best_coverage_train, best_rmse_train, best_test_width, best_coverage_test, best_rmse_test, best_pearson_r, best_ensembles, test_items = get_results(idx = 0, var_weights = 1.0, var_weight_weights = 4.0, var_D = 1, inflation_factor =1, fudging_beta = beta(1,19), 
           fudging_var = 5e-3, epochs = 20)
# Out:
# epoch number is 0
# Training Coverage, Widths, RMSE, and Pearson R
# 1.0 160.85264066704045 5.829540787798582 -0.016455089801858242
# Testing Coverage, Widths, RMSE, and Pearson R
# 1.0 160.72253904125537 5.855086611417921 -0.020684511928193032
# Patience is
# 0
#
#
# epoch number is 1
# Training Coverage, Widths, RMSE, and Pearson R
# 0.9912 113.68501134073047 23.14215901143646 0.16436792788877716
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.991 113.49453327286618 22.935413297589676 0.17922344726398018
# Patience is
# 1
#
#
# epoch number is 2
# Training Coverage, Widths, RMSE, and Pearson R
# 0.6144 51.366338887153034 26.451154943810895 -0.00873788155248219
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.639 51.0891160128189 26.10457696610982 0.017759683648085438
# Patience is
# 2
#
#
# epoch number is 3
# Training Coverage, Widths, RMSE, and Pearson R
# 0.6668 18.493192536467475 8.58780599445374 0.19903343066746776
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.676 18.353175702345673 8.513536998557147 0.203660620929351
# Patience is
# 3
#
#
# epoch number is 4
# Training Coverage, Widths, RMSE, and Pearson R
# 0.9776 15.019904793263564 3.095131361660155 0.430786559159135
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.979 14.817247204075287 3.0012375540366474 0.44038505484380874
# Patience is
# 0
#
#
# epoch number is 5
# Training Coverage, Widths, RMSE, and Pearson R
# 0.9984 15.126081096155572 1.7666869927479758 0.7861558056107377
# Testing Coverage, Widths, RMSE, and Pearson R
# 1.0 14.94437542019816 1.764517438010291 0.765600703275301
# Patience is
# 0
#
#
# epoch number is 6
# KeyboardInterrupt

# %%
data1_test, data2_test, data3_test, data4_test, y_test =  test_items

# %%
preds_test, _, _, _, _ = get_predictions_test(data1_test, data2_test, data3_test, data4_test, best_ensembles)

# %%
averaged_preds_test = preds_test.mean(0).reshape(-1,1)

# %%
plt.scatter(y_test, averaged_preds_test)
plt.axline((0,0), slope = 1, c = "black")
plt.xlabel("Ground Truth Values", fontsize = 15, fontweight = "bold")
plt.ylabel("MEnKF-ANN Predicted Values", fontsize = 15, fontweight = "bold")
plt.xticks(fontsize = 10, fontweight = "bold")
plt.yticks(fontsize = 10, fontweight = "bold")
plt.show()

# %%
items = [best_train_width, best_coverage_train, best_rmse_train, best_test_width, best_coverage_test, best_rmse_test, best_pearson_r]

# %%
items_df = pd.DataFrame(items).T

# %%
items_df.columns = ['best_train_width', 'best_coverage_train', 'best_rmse_train', 'best_test_width', 'best_coverage_test', 'best_rmse_test', 'best_pearson_r']

# %%
items_df = items_df.T

# %%
items_df.columns = ["Value"]

# %%
items_df
# Out:
#                          Value
# best_train_width     11.992684
# best_coverage_train   0.997200
# best_rmse_train       1.451088
# best_test_width      12.079126
# best_coverage_test    0.999000
# best_rmse_test        1.534123
# best_pearson_r        0.839067

# %%
preds_test.shape
# Out:
# (218, 1000)

# %%
random_idx = random.sample(range(y_test.shape[0]), k = 16)
fig, axs = plt.subplots(8, 2,figsize=(15, 15))
axs = axs.ravel()
for idx, i in enumerate(random_idx):
    # print(counter)
    truth = y_test[i,:]
    preds = preds_test[:, i]
    percts = np.percentile(preds, axis = 0, q = (2.5, 97.5))
    lis = percts[0]
    uis = percts[1]
    
    
    axs[idx].hist(preds)
    axs[idx].axvline(truth, color='green', linewidth=2)
    axs[idx].axvline(lis, color='red', linewidth=2)
    axs[idx].axvline(uis, color='red', linewidth=2)

# plt.title
fig.savefig('gcn_cdr_pred_intervals.png', bbox_inches='tight')
plt.show()

# %%
# plt.hist(y_train)
# plt.show()

# %%
plt.hist(y_test)
plt.show()

# %%
catch_overall = []

for idx in range(0,50): 
    best_train_width, best_coverage_train, best_rmse_train, best_test_width, best_coverage_test, best_rmse_test, best_pearson_r, _, _ = get_results(idx, var_weights = 2.0, var_weight_weights = 1.0, var_D = 1, inflation_factor =1, fudging_beta = beta(1,19), 
           fudging_var = 5e-3, epochs = 20)
    
    catch_overall.append([best_train_width, best_coverage_train, best_rmse_train, best_test_width, best_coverage_test, best_rmse_test, best_pearson_r])
# Out:
# epoch number is 0
# Training Coverage, Widths, RMSE, and Pearson R
# 1.0 227.47573027469534 7.998454489604203 -0.2568727857976921
# Testing Coverage, Widths, RMSE, and Pearson R
# 1.0 227.74428620523884 7.932309813202283 -0.29430480389995356
# Patience is
# 0
#
#
# epoch number is 1
# Training Coverage, Widths, RMSE, and Pearson R
# 1.0 83.5626343041737 9.618680580357035 0.0820106514731444
# Testing Coverage, Widths, RMSE, and Pearson R
# 1.0 84.044400987617 9.333994796414371 0.0985075388684067
# Patience is
# 1
#
#
# epoch number is 2
# Training Coverage, Widths, RMSE, and Pearson R
# 0.8332 20.486753545800905 7.182217888738779 0.22728310801052806
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.843 20.601448153131177 7.125611797983572 0.19888091222689158
# Patience is
# 0
#
#
# epoch number is 3
# Training Coverage, Widths, RMSE, and Pearson R
# 0.6164 6.004926436882632 3.3720623939756975 0.5391205554594074
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.613 6.027882880087652 3.3897843269620687 0.5216262329644802
# Patience is
# 0
#
#
# epoch number is 4
# Training Coverage, Widths, RMSE, and Pearson R
# 0.6252 3.439041725923258 1.9658445482094253 0.7255693235821759
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.614 3.4234747517758852 1.9718643673524854 0.7357897102707186
# Patience is
# 0
#
#
# epoch number is 5
# Training Coverage, Widths, RMSE, and Pearson R
# 0.7252 3.318013375822069 1.539907106158803 0.842793507462106
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.717 3.295014668388035 1.5558307489740113 0.8470375990794317
# Patience is
# 0
#
#
# epoch number is 6
# Training Coverage, Widths, RMSE, and Pearson R
# 0.7408 3.334828016046234 1.4792908485966099 0.8554933346594404
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.743 3.3190234056608436 1.5017039438813529 0.8570938717546482
# Patience is
# 0
#
#
# epoch number is 7
# Training Coverage, Widths, RMSE, and Pearson R
# 0.7488 3.3313294290119906 1.4721498991085675 0.8568767429895568
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.742 3.318319377616289 1.492151584294365 0.8588498755336095
# Patience is
# 0
#
#
# epoch number is 8
# Training Coverage, Widths, RMSE, and Pearson R
# 0.7604 3.4263974696257113 1.4702170993455046 0.8573283252685783
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.757 3.4046998541360303 1.4888982811614009 0.8593487582777671
# Patience is
# 0
#
#
# epoch number is 9
# Training Coverage, Widths, RMSE, and Pearson R
# 0.7488 3.321235781337438 1.469031361300052 0.8575331669569206
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.746 3.3009449834758 1.4865963029300584 0.8599292855711983
# Patience is
# 0
#
#
# epoch number is 10
# Training Coverage, Widths, RMSE, and Pearson R
# 0.7568 3.378099697104019 1.4669693325113844 0.857981738225607
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.74 3.3419524658121396 1.490066796458963 0.8592501711782855
# Patience is
# 0
#
#
# epoch number is 11
# Training Coverage, Widths, RMSE, and Pearson R
# 0.7596 3.400541716312464 1.4660776292668358 0.8581751630260639
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.754 3.3785936022094627 1.4950375038929367 0.8581285045479491
# Patience is
# 0
#
#
# epoch number is 12
# Training Coverage, Widths, RMSE, and Pearson R
# 0.7484 3.346440325141125 1.465176747017701 0.858350686147143
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.757 3.312185878714699 1.4897249503248147 0.8592377439157718
# Patience is
# 0
#
#
# epoch number is 13
# Training Coverage, Widths, RMSE, and Pearson R
# 0.7508 3.3985636816482905 1.464763612499653 0.8584381538019114
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.748 3.3872769797080986 1.4902499784799306 0.8590667712089052
# Patience is
# 0
#
#
# epoch number is 14
# Training Coverage, Widths, RMSE, and Pearson R
# 0.746 3.3134914739733627 1.4658471870004115 0.8582168092950825
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.748 3.2803066415445654 1.484802927248049 0.8601903430032011
# Patience is
# 1
#
#
# epoch number is 15
# Training Coverage, Widths, RMSE, and Pearson R
# 0.7496 3.3215800512989127 1.4645121412505757 0.8584931514280192
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.738 3.2875388341426532 1.4964131715737876 0.8578146830575357
# Patience is
# 0
#
#
# epoch number is 16
# Training Coverage, Widths, RMSE, and Pearson R
# 0.7432 3.30046374342922 1.4636324090378972 0.8586669914859797
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.739 3.27662088660054 1.490693087209518 0.8590590160560749
# Patience is
# 0
#
#
# epoch number is 17
# Training Coverage, Widths, RMSE, and Pearson R
# 0.7368 3.2684335829371745 1.4659034308986185 0.8583615878180126
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.733 3.2469097284040997 1.492344911584552 0.8589921963547434
# Patience is
# 1
#
#
# epoch number is 18
# Training Coverage, Widths, RMSE, and Pearson R
# 0.7544 3.3447074944079445 1.4637828208293922 0.8586538091366879
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.748 3.318915728131561 1.4900535387689802 0.8591079980377186
# Patience is
# 2
#
#
# epoch number is 19
# Training Coverage, Widths, RMSE, and Pearson R
# 0.7428 3.295926361917807 1.4645644107887255 0.8585447075982292
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.737 3.2701263649484154 1.4925659345670963 0.8586146754240003
# Patience is
# 3
#
#
# train_coverage0.7432
# test_coverage0.739
# train_width3.30046374342922
# test_width3.27662088660054
# pearson0.8590590160560749
# rmse_train1.4636324090378972
# rmse_test1.490693087209518
# epoch number is 0
# Training Coverage, Widths, RMSE, and Pearson R
# 1.0 262.34727884979145 6.89932244271704 0.021689587189202383
# Testing Coverage, Widths, RMSE, and Pearson R
# 1.0 262.12365081372536 7.040226901839799 -0.08888193265424695
# Patience is
# 0
#
#
# epoch number is 1
# Training Coverage, Widths, RMSE, and Pearson R
# 1.0 120.07229647008474 11.220629972229805 -0.36869985290759627
# Testing Coverage, Widths, RMSE, and Pearson R
# 1.0 120.64119243713098 11.450700370483037 -0.366809575914987
# Patience is
# 1
#
#
# epoch number is 2
# Training Coverage, Widths, RMSE, and Pearson R
# 0.9432 43.22101907598229 11.1962292051071 0.1026774864615713
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.934 43.29364057806575 11.686880563516675 0.027355885585550563
# Patience is
# 2
#
#
# epoch number is 3
# Training Coverage, Widths, RMSE, and Pearson R
# 0.7868 17.276806848483456 7.031300955372285 0.16770463684340342
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.785 17.242704803221198 6.980828159511316 0.1303892531278764
# Patience is
# 3
#
#
# epoch number is 4
# Training Coverage, Widths, RMSE, and Pearson R
# 0.9732 12.533814045223753 2.710080991298859 0.6756987604999812
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.974 12.51166330353277 2.750091995464632 0.6235959859749466
# Patience is
# 0
#
#
# epoch number is 5
# Training Coverage, Widths, RMSE, and Pearson R
# 0.9928 11.787624048533047 1.7969126243873677 0.7890299180096926
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.991 11.78882865044039 1.7636240551541797 0.7697608044807497
# Patience is
# 0
#
#
# epoch number is 6
# Training Coverage, Widths, RMSE, and Pearson R
# 0.9936 11.977790245886167 1.6530419062697792 0.824788015669934
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.992 11.994567186955617 1.6611478890306475 0.7981600524748401
# Patience is
# 0
#
#
# epoch number is 7
# Training Coverage, Widths, RMSE, and Pearson R
# 0.9968 12.669894146950531 1.607907765937864 0.8351598552858487
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.995 12.596233882720076 1.614584797717637 0.8097627364209797
# Patience is
# 0
#
#
# epoch number is 8
# Training Coverage, Widths, RMSE, and Pearson R
# 0.996 12.194465316644335 1.6195909467187561 0.8324452356142455
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.994 12.172350326725283 1.6130521644161717 0.8102640649952197
# Patience is
# 1
#
#
# epoch number is 9
# Training Coverage, Widths, RMSE, and Pearson R
# 0.9952 11.976062223968572 1.573404237763386 0.842690094924482
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.993 11.98935632570627 1.5715847333319795 0.821322213048893
# Patience is
# 0
#
#
# epoch number is 10
# Training Coverage, Widths, RMSE, and Pearson R
# 0.9968 11.630583900550702 1.5577743693287949 0.8461328466449898
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.995 11.632001752940472 1.5522010560907253 0.8260009454585049
# Patience is
# 0
#
#
# epoch number is 11
# Training Coverage, Widths, RMSE, and Pearson R
# 0.9952 11.653342297619979 1.5390145578684 0.8505025717299239
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.993 11.639952820090214 1.5351192391604198 0.8321877002303975
# Patience is
# 0
#
#
# epoch number is 12
# Training Coverage, Widths, RMSE, and Pearson R
# 0.9952 11.406309249173269 1.5370249123231763 0.8508788704115442
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.992 11.394753855698498 1.5297368273730734 0.8311439457686409
# Patience is
# 0
#
#
# epoch number is 13
# Training Coverage, Widths, RMSE, and Pearson R
# 0.9936 11.555532459982429 1.5449380022527406 0.8519322549842984
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.994 11.590146139201675 1.5574178033713746 0.8325823487874267
# Patience is
# 1
#
#
# epoch number is 14
# Training Coverage, Widths, RMSE, and Pearson R
# 0.9944 11.328481717965648 1.5455142029457967 0.8498434296677368
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.989 11.331297912724162 1.5461455883906612 0.8306653055044103
# Patience is
# 2
#
#
# epoch number is 15
# Training Coverage, Widths, RMSE, and Pearson R
# 0.9944 11.370872019725464 1.5505287972603798 0.8479396444581524
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.993 11.370569278380717 1.5525940918366765 0.8269409430322354
# Patience is
# 3
#
#
# epoch number is 16
# Training Coverage, Widths, RMSE, and Pearson R
# 0.9952 11.340712672680183 1.5180122657908297 0.8545256435798426
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.991 11.32737034119714 1.5229379148399127 0.834217694517581
# Patience is
# 0
#
#
# epoch number is 17
# Training Coverage, Widths, RMSE, and Pearson R
# 0.9924 11.031322312055956 1.5389205369483283 0.8505113611727437
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.989 11.022404890455483 1.541339409007789 0.8317083690081961
# Patience is
# 1
#
#
# epoch number is 18
# Training Coverage, Widths, RMSE, and Pearson R
# 0.9932 10.952121913286373 1.529993563981173 0.8520620822777453
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.989 10.973387512697794 1.5379710082936007 0.8306031840889315
# Patience is
# 2
#
#
# epoch number is 19
# Training Coverage, Widths, RMSE, and Pearson R
# 0.9956 11.045076355745874 1.5275747134761513 0.8531543172041594
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.992 11.056296144229972 1.5430225088454268 0.83145061098684
# Patience is
# 3
#
#
# train_coverage0.9952
# test_coverage0.991
# train_width11.340712672680183
# test_width11.32737034119714
# pearson0.834217694517581
# rmse_train1.5180122657908297
# rmse_test1.5229379148399127
# epoch number is 0
# Training Coverage, Widths, RMSE, and Pearson R
# 1.0 226.42267807860267 6.785601752877138 0.23066921668760335
# Testing Coverage, Widths, RMSE, and Pearson R
# 1.0 225.59384750438596 6.694767021343873 0.21679420020431311
# Patience is
# 0
#
#
# epoch number is 1
# Training Coverage, Widths, RMSE, and Pearson R
# 1.0 100.83590488122478 11.843951524723474 0.015286694254645392
# Testing Coverage, Widths, RMSE, and Pearson R
# 1.0 99.49842243470816 11.577626733655686 -0.010557465941564214
# Patience is
# 1
#
#
# epoch number is 2
# Training Coverage, Widths, RMSE, and Pearson R
# 0.8028 31.56085749530699 12.690335924526385 0.32890042414019244
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.834 31.25090774855387 12.109296060844983 0.3495321689326894
# Patience is
# 2
#
#
# epoch number is 3
# Training Coverage, Widths, RMSE, and Pearson R
# 0.6488 8.971257287457751 4.9850523227834795 0.4883726931501254
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.671 8.820949240458951 4.678980647901114 0.503387152261828
# Patience is
# 0
#
#
# epoch number is 4
# Training Coverage, Widths, RMSE, and Pearson R
# 0.9064 6.446761559490496 1.94037034867663 0.7447288895554863
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.913 6.337258849039907 1.8561526474071859 0.7517948460397157
# Patience is
# 0
#
#
# epoch number is 5
# Training Coverage, Widths, RMSE, and Pearson R
# 0.9444 6.007955402707468 1.5230429870962048 0.8353014793126318
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.926 5.881235304583952 1.516466832604037 0.8264743478234612
# Patience is
# 0
#
#
# epoch number is 6
# Training Coverage, Widths, RMSE, and Pearson R
# 0.9296 5.772199264135981 1.4603956789847063 0.8497587196121312
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.917 5.658466728349447 1.467244236581677 0.8385717919555025
# Patience is
# 0
#
#
# epoch number is 7
# Training Coverage, Widths, RMSE, and Pearson R
# 0.93 5.727619926242373 1.4520870606584035 0.8513449341960946
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.921 5.624119839823428 1.473682130590142 0.8379142530563579
# Patience is
# 0
#
#
# epoch number is 8
# Training Coverage, Widths, RMSE, and Pearson R
# 0.9248 5.5421102191000955 1.4523328592723448 0.8514137646130593
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.915 5.425436625377037 1.4737449822448927 0.8373557830407868
# Patience is
# 1
#
#
# epoch number is 9
# Training Coverage, Widths, RMSE, and Pearson R
# 0.9256 5.550511670159804 1.4513537367997758 0.8515053808842129
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.92 5.433567637613925 1.4598084183724105 0.8408326391962824
# Patience is
# 0
#
#
# epoch number is 10
# Training Coverage, Widths, RMSE, and Pearson R
# 0.9228 5.467763937721418 1.4471560229024694 0.8524657491797737
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.913 5.358750680045649 1.4680508650154933 0.8394025605312387
# Patience is
# 0
#
#
# epoch number is 11
# Training Coverage, Widths, RMSE, and Pearson R
# 0.9204 5.549133022016309 1.4502437649949425 0.8518481068541964
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.91 5.431350100450205 1.4724428183577125 0.8386721894879685
# Patience is
# 1
#
#
# epoch number is 12
# Training Coverage, Widths, RMSE, and Pearson R
# 0.9236 5.60170593295473 1.4473822125914986 0.852448464539099
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.918 5.466079149199051 1.4756490733524308 0.8378945855152974
# Patience is
# 2
#
#
# epoch number is 13
# Training Coverage, Widths, RMSE, and Pearson R
# 0.9192 5.407351727420778 1.4450089124601833 0.8528727438487896
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.906 5.28668577626789 1.4714028721175159 0.8382205053501757
# Patience is
# 0
#
#
# epoch number is 14
# Training Coverage, Widths, RMSE, and Pearson R
# 0.9196 5.486313752383928 1.4464990997883556 0.8526448043942261
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.916 5.355457441760796 1.4678870017139154 0.838757309048249
# Patience is
# 1
#
#
# epoch number is 15
# Training Coverage, Widths, RMSE, and Pearson R
# 0.9216 5.50353951699706 1.4460797301350239 0.8526523280207998
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.921 5.405321882141731 1.465728900835114 0.8393703666629225
# Patience is
# 2
#
#
# epoch number is 16
# Training Coverage, Widths, RMSE, and Pearson R
# 0.918 5.385858210084636 1.4476101761163842 0.85255471743172
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.91 5.271995767986546 1.4704162348179426 0.8392560819021925
# Patience is
# 3
#
#
# epoch number is 17
# Training Coverage, Widths, RMSE, and Pearson R
# 0.918 5.418988843342417 1.445017053372834 0.8528821118013914
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.909 5.321904770490472 1.473103481059674 0.8376942637954485
# Patience is
# 4
#
#
# epoch number is 18
# Training Coverage, Widths, RMSE, and Pearson R
# 0.9156 5.294746029364751 1.4467959497489022 0.852620264057435
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.914 5.187777350020913 1.471563132127998 0.8389242317872044
# Patience is
# 5
#
#
# epoch number is 19
# Training Coverage, Widths, RMSE, and Pearson R
# 0.9132 5.351267779524771 1.4464948088726308 0.8526521374022992
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.9 5.242447063124079 1.4799270070940957 0.8358686194504509
# Patience is
# 6
#
#
# train_coverage0.9192
# test_coverage0.906
# train_width5.407351727420778
# test_width5.28668577626789
# pearson0.8382205053501757
# rmse_train1.4450089124601833
# rmse_test1.4714028721175159
# epoch number is 0
# Training Coverage, Widths, RMSE, and Pearson R
# 1.0 276.39829494330445 13.857078027201673 -0.3659047396564783
# Testing Coverage, Widths, RMSE, and Pearson R
# 1.0 275.56110103026754 13.525131936086249 -0.34979616485163834
# Patience is
# 0
#
#
# epoch number is 1
# Training Coverage, Widths, RMSE, and Pearson R
# 1.0 156.85184720381383 19.673074486160225 -0.3697995750566163
# Testing Coverage, Widths, RMSE, and Pearson R
# 1.0 157.15645173449138 20.188493946729462 -0.3894365715924143
# Patience is
# 1
#
#
# epoch number is 2
# Training Coverage, Widths, RMSE, and Pearson R
# 0.6312 73.14066954172469 37.081318953346795 -0.3271798283463033
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.667 73.16240006611365 35.799054620747384 -0.3299464903509446
# Patience is
# 2
#
#
# epoch number is 3
# Training Coverage, Widths, RMSE, and Pearson R
# 0.6212 24.23195913521414 13.0623710004829 -0.14895608957591136
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.655 24.27223830933941 12.462258238833309 -0.14660965119636712
# Patience is
# 0
#
#
# epoch number is 4
# Training Coverage, Widths, RMSE, and Pearson R
# 0.9584 17.8661666325222 4.400061116971856 0.25139305476799306
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.952 17.997114744712583 4.441548560825688 0.2603433463556376
# Patience is
# 0
#
#
# epoch number is 5
# Training Coverage, Widths, RMSE, and Pearson R
# 0.9988 15.386053223369212 1.8128845198865637 0.7708805570752508
# Testing Coverage, Widths, RMSE, and Pearson R
# 1.0 15.479562820856012 1.7964987068738403 0.7638403260876294
# Patience is
# 0
#
#
# epoch number is 6
# Training Coverage, Widths, RMSE, and Pearson R
# 0.9992 15.508748041232408 1.5598957689549928 0.8331517705163336
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.999 15.619113643889774 1.5700821904240032 0.8276872036743411
# Patience is
# 0
#
#
# epoch number is 7
# Training Coverage, Widths, RMSE, and Pearson R
# 0.9992 15.157899606904266 1.4708258196524995 0.8538409766623096
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.999 15.28834258236345 1.500986607353556 0.8451492630948523
# Patience is
# 0
#
#
# epoch number is 8
# Training Coverage, Widths, RMSE, and Pearson R
# 0.9996 15.216585592379616 1.4853141068956537 0.8499776014363801
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.999 15.318865524415736 1.5440332597050548 0.8334951661068294
# Patience is
# 1
#
#
# epoch number is 9
# Training Coverage, Widths, RMSE, and Pearson R
# 0.9992 15.138939688035641 1.4690246866462833 0.8534547361417886
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.999 15.218800468030418 1.5155491527488532 0.8389433794983139
# Patience is
# 0
#
#
# epoch number is 10
# Training Coverage, Widths, RMSE, and Pearson R
# 0.9992 14.395131808725232 1.4580633852045812 0.8558487612497898
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.998 14.466499242804383 1.4811730154857063 0.8465498289008295
# Patience is
# 0
#
#
# epoch number is 11
# Training Coverage, Widths, RMSE, and Pearson R
# 0.9992 14.162108444327762 1.4576491913507261 0.8560358016529817
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.999 14.244786935173936 1.4951014748543712 0.8449932568798129
# Patience is
# 0
#
#
# epoch number is 12
# Training Coverage, Widths, RMSE, and Pearson R
# 0.9996 14.437219380118849 1.4486714209718778 0.8578236917837354
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.999 14.52906643390447 1.4868182833596058 0.8462159805570452
# Patience is
# 0
#
#
# epoch number is 13
# Training Coverage, Widths, RMSE, and Pearson R
# 0.9996 13.954897732550855 1.4525953613577667 0.8578869488431379
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.998 14.033559640505182 1.4961345075620256 0.8473998530421656
# Patience is
# 1
#
#
# epoch number is 14
# Training Coverage, Widths, RMSE, and Pearson R
# 0.9992 13.928704948212381 1.4721847138992352 0.8540356829208147
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.998 13.994825694739733 1.5322757457555354 0.8395621849513163
# Patience is
# 2
#
#
# epoch number is 15
# Training Coverage, Widths, RMSE, and Pearson R
# 0.9988 13.56759268065257 1.448007000136795 0.857997827828009
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.999 13.683339676487297 1.4903646381246687 0.8450634763182918
# Patience is
# 0
#
#
# epoch number is 16
# Training Coverage, Widths, RMSE, and Pearson R
# 0.9988 13.307756399796437 1.4548638679758341 0.857089106657986
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.997 13.364811013185856 1.5093829451658767 0.8440612862950432
# Patience is
# 1
#
#
# epoch number is 17
# Training Coverage, Widths, RMSE, and Pearson R
# 0.9988 13.55820339821985 1.4491423611360077 0.8577109533753495
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.997 13.648155833588117 1.4963392536434237 0.8438462907200951
# Patience is
# 2
#
#
# epoch number is 18
# Training Coverage, Widths, RMSE, and Pearson R
# 0.9988 13.128398705187239 1.4621128750108185 0.8550992724922891
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.997 13.19926513502951 1.518452253860637 0.8404666017654192
# Patience is
# 3
#
#
# epoch number is 19
# Training Coverage, Widths, RMSE, and Pearson R
# 0.9988 13.564406110842851 1.462724373250541 0.8548646820675672
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.997 13.659706963416072 1.51985141141185 0.8385801508098467
# Patience is
# 4
#
#
# train_coverage0.9988
# test_coverage0.999
# train_width13.56759268065257
# test_width13.683339676487297
# pearson0.8450634763182918
# rmse_train1.448007000136795
# rmse_test1.4903646381246687
# epoch number is 0
# Training Coverage, Widths, RMSE, and Pearson R
# 1.0 262.8996302115555 7.45466662125399 0.23546777542231226
# Testing Coverage, Widths, RMSE, and Pearson R
# 1.0 257.4348735491615 7.496530715558989 0.21008453871703872
# Patience is
# 0
#
#
# epoch number is 1
# Training Coverage, Widths, RMSE, and Pearson R
# 1.0 69.69517300471955 6.156910474745311 0.011988689969562105
# Testing Coverage, Widths, RMSE, and Pearson R
# 1.0 68.17524094958894 6.14754544698971 0.0006216990284837262
# Patience is
# 0
#
#
# epoch number is 2
# Training Coverage, Widths, RMSE, and Pearson R
# 0.8556 26.685715662012303 7.932419720223269 0.08030382095430423
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.83 26.12459542049345 8.104191965281592 0.02121752088913348
# Patience is
# 1
#
#
# epoch number is 3
# Training Coverage, Widths, RMSE, and Pearson R
# 0.708 8.01487028390019 3.764918945131804 0.43005170224567546
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.686 7.865245187475436 3.840578781417486 0.39520142032102223
# Patience is
# 0
#
#
# epoch number is 4
# Training Coverage, Widths, RMSE, and Pearson R
# 0.8288 5.46884790721071 1.9569159284155009 0.7353132758165148
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.793 5.37915098863351 2.04676063338607 0.7199189825730612
# Patience is
# 0
#
#
# epoch number is 5
# Training Coverage, Widths, RMSE, and Pearson R
# 0.8592 4.785015107475998 1.5971554258145906 0.8292713099335751
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.83 4.699975960329251 1.6745948310112388 0.8213352127787715
# Patience is
# 0
#
#
# epoch number is 6
# Training Coverage, Widths, RMSE, and Pearson R
# 0.8904 4.8522756556018125 1.4867202259302748 0.8526015466637782
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.858 4.76899322552663 1.5692690202319064 0.8426385867977433
# Patience is
# 0
#
#
# epoch number is 7
# Training Coverage, Widths, RMSE, and Pearson R
# 0.8768 4.690961948846964 1.4732591941756166 0.8553700261817198
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.86 4.6134585015697045 1.55265097452343 0.8461972805233464
# Patience is
# 0
#
#
# epoch number is 8
# Training Coverage, Widths, RMSE, and Pearson R
# 0.8732 4.540094683938226 1.4670133402270564 0.8567819762041844
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.847 4.480935061229031 1.5389932529428234 0.8492708124368865
# Patience is
# 0
#
#
# epoch number is 9
# Training Coverage, Widths, RMSE, and Pearson R
# 0.8716 4.488521599008579 1.462023190505758 0.8576853664512004
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.837 4.413049432575317 1.5316370089294906 0.8504386074595847
# Patience is
# 0
#
#
# epoch number is 10
# Training Coverage, Widths, RMSE, and Pearson R
# 0.8636 4.397447556645436 1.4609619488644048 0.8579370708334249
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.84 4.321979281863964 1.5288629106006266 0.8509465337737594
# Patience is
# 0
#
#
# epoch number is 11
# Training Coverage, Widths, RMSE, and Pearson R
# 0.8592 4.349721008099752 1.4594459533299289 0.8582681388693716
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.827 4.285568662330696 1.5367693234468944 0.8492440630531756
# Patience is
# 0
#
#
# epoch number is 12
# Training Coverage, Widths, RMSE, and Pearson R
# 0.854 4.290643244249204 1.4571927820152908 0.8587040809893067
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.83 4.236230223352689 1.5278775872215318 0.8511825748542619
# Patience is
# 0
#
#
# epoch number is 13
# Training Coverage, Widths, RMSE, and Pearson R
# 0.8508 4.216882740828758 1.456372988896021 0.8589086884734695
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.817 4.140500715193659 1.5314356150089627 0.8506067814665015
# Patience is
# 0
#
#
# epoch number is 14
# Training Coverage, Widths, RMSE, and Pearson R
# 0.848 4.184709587097995 1.4562152672042257 0.8589067936626902
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.82 4.126976815547366 1.5283753388349022 0.8511365997869565
# Patience is
# 0
#
#
# epoch number is 15
# Training Coverage, Widths, RMSE, and Pearson R
# 0.8528 4.2761224100909105 1.4556254721125268 0.8590743979839056
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.833 4.206999857388637 1.5279233575113895 0.8511810218860196
# Patience is
# 0
#
#
# epoch number is 16
# Training Coverage, Widths, RMSE, and Pearson R
# 0.8428 4.175996373547792 1.456167251072484 0.8589281308080091
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.819 4.1070303664221495 1.5299556716107179 0.8508758012838468
# Patience is
# 1
#
#
# epoch number is 17
# Training Coverage, Widths, RMSE, and Pearson R
# 0.8404 4.176242666721719 1.4559429951611376 0.8589632430012609
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.826 4.10916308039136 1.5337040704972769 0.8499809178045704
# Patience is
# 2
#
#
# epoch number is 18
# Training Coverage, Widths, RMSE, and Pearson R
# 0.8388 4.136620382724338 1.4547082434372753 0.8592280737382597
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.812 4.062963270407496 1.5314808827539952 0.8504951668434689
# Patience is
# 0
#
#
# epoch number is 19
# Training Coverage, Widths, RMSE, and Pearson R
# 0.8488 4.188200241244839 1.4555698286692385 0.8590688828817469
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.819 4.127076323324525 1.5300791855866724 0.8509190926983439
# Patience is
# 1
#
#
# train_coverage0.8388
# test_coverage0.812
# train_width4.136620382724338
# test_width4.062963270407496
# pearson0.8504951668434689
# rmse_train1.4547082434372753
# rmse_test1.5314808827539952
# epoch number is 0
# Training Coverage, Widths, RMSE, and Pearson R
# 1.0 258.12190300240934 9.262537668363414 0.3016097174252871
# Testing Coverage, Widths, RMSE, and Pearson R
# 1.0 258.26331208322654 9.549600628380347 0.3059759828401625
# Patience is
# 0
#
#
# epoch number is 1
# Training Coverage, Widths, RMSE, and Pearson R
# 1.0 112.77360755337486 12.714072866042834 -0.16900000384252511
# Testing Coverage, Widths, RMSE, and Pearson R
# 1.0 112.23829065555287 12.263877909134795 -0.14629565430608585
# Patience is
# 1
#
#
# epoch number is 2
# Training Coverage, Widths, RMSE, and Pearson R
# 0.8152 29.427017558185913 10.56930503352861 0.11851349792548024
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.814 29.441830166749 10.782502063429211 0.1396738379332881
# Patience is
# 2
#
#
# epoch number is 3
# Training Coverage, Widths, RMSE, and Pearson R
# 0.6304 10.979148939634094 6.086415697483749 -0.26390508855040157
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.614 10.938749944380062 6.2579553995001405 -0.2711925471632292
# Patience is
# 0
#
#
# epoch number is 4
# Training Coverage, Widths, RMSE, and Pearson R
# 0.8564 6.54761691817937 2.109249026075268 0.6595359240492554
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.856 6.548990172250973 2.1480965244978245 0.6301439206904481
# Patience is
# 0
#
#
# epoch number is 5
# Training Coverage, Widths, RMSE, and Pearson R
# 0.9268 6.282978095292079 1.6385521971175232 0.8129417731587232
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.917 6.2999791578450886 1.7187391059378814 0.7843933221567102
# Patience is
# 0
#
#
# epoch number is 6
# Training Coverage, Widths, RMSE, and Pearson R
# 0.924 5.985912646574754 1.5222297850663244 0.8449997951783665
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.916 5.991187068387604 1.6304743822294174 0.8122913912485954
# Patience is
# 0
#
#
# epoch number is 7
# Training Coverage, Widths, RMSE, and Pearson R
# 0.9436 5.992758653659757 1.440872551846046 0.858381717646697
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.93 5.985863022160839 1.5666897484364573 0.8238678415021251
# Patience is
# 0
#
#
# epoch number is 8
# Training Coverage, Widths, RMSE, and Pearson R
# 0.9396 5.908573013678047 1.4118521264528003 0.8640165778424008
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.927 5.9209041817704335 1.525204132397122 0.8340345547984913
# Patience is
# 0
#
#
# epoch number is 9
# Training Coverage, Widths, RMSE, and Pearson R
# 0.9496 6.317057016349453 1.4070456386622139 0.8651525756279106
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.943 6.331034080487067 1.5185637699550838 0.8360937402484916
# Patience is
# 0
#
#
# epoch number is 10
# Training Coverage, Widths, RMSE, and Pearson R
# 0.9452 6.071808319317485 1.400580909257704 0.8663375536709966
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.934 6.110085811835689 1.510044562387727 0.8377640517103416
# Patience is
# 0
#
#
# epoch number is 11
# Training Coverage, Widths, RMSE, and Pearson R
# 0.942 5.8708580607714875 1.398091187161409 0.8668979291737826
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.927 5.880434843427376 1.5136497559659259 0.8371081047179154
# Patience is
# 0
#
#
# epoch number is 12
# Training Coverage, Widths, RMSE, and Pearson R
# 0.946 5.982076151629162 1.4013233380760313 0.8662326697116398
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.936 6.001046248020637 1.517152024866973 0.8362610394624276
# Patience is
# 1
#
#
# epoch number is 13
# Training Coverage, Widths, RMSE, and Pearson R
# 0.9424 5.950442091373864 1.3999216610592682 0.8664842106070934
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.935 5.972200571302994 1.5173027746691483 0.8359115935933696
# Patience is
# 2
#
#
# epoch number is 14
# Training Coverage, Widths, RMSE, and Pearson R
# 0.9428 5.8957744963053935 1.4032349650884146 0.8659794581566066
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.928 5.89486646553334 1.5182372555045405 0.8356059333401233
# Patience is
# 3
#
#
# epoch number is 15
# Training Coverage, Widths, RMSE, and Pearson R
# 0.9368 5.931363084637082 1.3976427760896972 0.8669273765670076
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.923 5.932029924503126 1.5148178153313792 0.8365863771137261
# Patience is
# 0
#
#
# epoch number is 16
# Training Coverage, Widths, RMSE, and Pearson R
# 0.9432 5.997854097666361 1.3971829897328498 0.8670194895960707
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.933 5.993760589988251 1.5123739639081746 0.8371544320393371
# Patience is
# 0
#
#
# epoch number is 17
# Training Coverage, Widths, RMSE, and Pearson R
# 0.9396 5.857763166820115 1.4005754895012001 0.8664443575712771
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.926 5.8619479023155945 1.5193751581141175 0.8354141337396934
# Patience is
# 1
#
#
# epoch number is 18
# Training Coverage, Widths, RMSE, and Pearson R
# 0.9452 6.045120912015326 1.397758386576232 0.8670796739688558
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.931 6.064263440747527 1.506523067268306 0.8390112568040625
# Patience is
# 2
#
#
# epoch number is 19
# Training Coverage, Widths, RMSE, and Pearson R
# 0.9432 5.875846100915857 1.3963789942807134 0.8672311028918648
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.924 5.877752071441041 1.5041597737111931 0.8393479344194604
# Patience is
# 0
#
#
# train_coverage0.9432
# test_coverage0.924
# train_width5.875846100915857
# test_width5.877752071441041
# pearson0.8393479344194604
# rmse_train1.3963789942807134
# rmse_test1.5041597737111931
# epoch number is 0
# Training Coverage, Widths, RMSE, and Pearson R
# 1.0 277.4781910036276 8.187136984575 -0.10039470161370091
# Testing Coverage, Widths, RMSE, and Pearson R
# 1.0 271.92035832072827 7.569464956152431 -0.10725716129629004
# Patience is
# 0
#
#
# epoch number is 1
# Training Coverage, Widths, RMSE, and Pearson R
# 1.0 115.30478295567278 13.948555829399801 0.07685400401766947
# Testing Coverage, Widths, RMSE, and Pearson R
# 1.0 113.16519026308112 13.942233001171012 0.07859103539988309
# Patience is
# 1
#
#
# epoch number is 2
# Training Coverage, Widths, RMSE, and Pearson R
# 0.9832 37.0340451463594 8.91112956829219 -0.05444325756602883
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.979 35.78907657427175 8.565492268795817 -0.115083851671945
# Patience is
# 2
#
#
# epoch number is 3
# Training Coverage, Widths, RMSE, and Pearson R
# 0.6656 10.112585832003877 5.096966677014604 0.2924610941657916
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.698 9.949848932141238 4.900634357924601 0.30117367416316176
# Patience is
# 0
#
#
# epoch number is 4
# Training Coverage, Widths, RMSE, and Pearson R
# 0.8784 7.034024115760258 2.2187150028636613 0.6691951477278069
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.878 6.927949917877269 2.2227956546088796 0.6985964930105018
# Patience is
# 0
#
#
# epoch number is 5
# Training Coverage, Widths, RMSE, and Pearson R
# 0.9352 6.686887324496862 1.6681229109194686 0.8016617632835366
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.936 6.589302613382839 1.7192770457773499 0.8117163962659317
# Patience is
# 0
#
#
# epoch number is 6
# Training Coverage, Widths, RMSE, and Pearson R
# 0.9456 6.406083027196694 1.4997537672900376 0.8425167382800733
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.942 6.332673831670257 1.5694265411400359 0.8444405347222764
# Patience is
# 0
#
#
# epoch number is 7
# Training Coverage, Widths, RMSE, and Pearson R
# 0.9508 6.43255857421022 1.4706519459749938 0.8491154325035037
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.95 6.364666414607936 1.5482099705080434 0.8488985645994024
# Patience is
# 0
#
#
# epoch number is 8
# Training Coverage, Widths, RMSE, and Pearson R
# 0.9504 6.464070887013932 1.4580371831618264 0.8521833853193614
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.942 6.393168049286562 1.5255449374135033 0.8538578145108883
# Patience is
# 0
#
#
# epoch number is 9
# Training Coverage, Widths, RMSE, and Pearson R
# 0.9516 6.546293661213426 1.4444276654540251 0.8549053370886129
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.951 6.447624107122878 1.509228028258806 0.8570608918021716
# Patience is
# 0
#
#
# epoch number is 10
# Training Coverage, Widths, RMSE, and Pearson R
# 0.952 6.489240358723122 1.4475871399074152 0.8542087518769752
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.949 6.406814810163491 1.510274584773913 0.8568613715147879
# Patience is
# 1
#
#
# epoch number is 11
# Training Coverage, Widths, RMSE, and Pearson R
# 0.9532 6.481065166672847 1.4420746305288823 0.8554187743184238
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.946 6.395464000815154 1.5037768862078076 0.8581710086711146
# Patience is
# 0
#
#
# epoch number is 12
# Training Coverage, Widths, RMSE, and Pearson R
# 0.9536 6.561351390678808 1.4422726590235697 0.8553730320002395
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.947 6.4677907908232175 1.5038253969559021 0.8581461027835997
# Patience is
# 1
#
#
# epoch number is 13
# Training Coverage, Widths, RMSE, and Pearson R
# 0.9516 6.485690035735954 1.4419079670328083 0.8554488057279055
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.947 6.395866451868325 1.5079351465970436 0.8573139021047966
# Patience is
# 0
#
#
# epoch number is 14
# Training Coverage, Widths, RMSE, and Pearson R
# 0.958 6.783753882979963 1.4438335446907231 0.8550438809592342
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.953 6.703964263064657 1.5098000737994464 0.8569771337709372
# Patience is
# 1
#
#
# epoch number is 15
# Training Coverage, Widths, RMSE, and Pearson R
# 0.958 6.660936121870851 1.4440888750722032 0.8550183495225092
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.951 6.610398020619761 1.5070449158662718 0.8575899123112455
# Patience is
# 2
#
#
# epoch number is 16
# Training Coverage, Widths, RMSE, and Pearson R
# 0.9604 6.765975145433056 1.4413601033872132 0.8555674477564711
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.963 6.702332084861158 1.5078340779979569 0.857348122821101
# Patience is
# 0
#
#
# epoch number is 17
# Training Coverage, Widths, RMSE, and Pearson R
# 0.9544 6.661149894071661 1.4458763741149627 0.8546638491121583
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.95 6.591699631487356 1.5099919759794331 0.8569541869494266
# Patience is
# 1
#
#
# epoch number is 18
# Training Coverage, Widths, RMSE, and Pearson R
# 0.9536 6.513889215210744 1.441527457459813 0.8555458340528346
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.949 6.416469626765267 1.5072645336752928 0.8575007786187187
# Patience is
# 2
#
#
# epoch number is 19
# Training Coverage, Widths, RMSE, and Pearson R
# 0.9616 6.823189817996836 1.4428914908472306 0.8553163884635165
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.951 6.738905562255126 1.5111683335750052 0.8567710153969127
# Patience is
# 3
#
#
# train_coverage0.9604
# test_coverage0.963
# train_width6.765975145433056
# test_width6.702332084861158
# pearson0.857348122821101
# rmse_train1.4413601033872132
# rmse_test1.5078340779979569
# epoch number is 0
# Training Coverage, Widths, RMSE, and Pearson R
# 1.0 255.3501700280521 6.7382776053783076 -0.14093487241130523
# Testing Coverage, Widths, RMSE, and Pearson R
# 1.0 256.24632182811234 6.789628200549598 -0.10620813611340946
# Patience is
# 0
#
#
# epoch number is 1
# Training Coverage, Widths, RMSE, and Pearson R
# 1.0 114.34928779511955 13.167194387482509 -0.31054652004691563
# Testing Coverage, Widths, RMSE, and Pearson R
# 1.0 114.64287627781492 13.512447377528055 -0.3356430877434176
# Patience is
# 1
#
#
# epoch number is 2
# Training Coverage, Widths, RMSE, and Pearson R
# 0.8008 25.9065702892866 9.734544382221856 -0.19256576996930969
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.792 25.940561562210032 9.877266801968407 -0.19111576950598982
# Patience is
# 2
#
#
# epoch number is 3
# Training Coverage, Widths, RMSE, and Pearson R
# 0.6228 7.869983251441019 4.379488095850413 0.053387759490094305
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.602 7.898812785762159 4.517712340629266 0.025482233958365137
# Patience is
# 0
#
#
# epoch number is 4
# Training Coverage, Widths, RMSE, and Pearson R
# 0.7104 4.257964516565718 1.9914887063735516 0.7298226126828259
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.689 4.2652386403770794 2.060760467912157 0.7123022060306524
# Patience is
# 0
#
#
# epoch number is 5
# Training Coverage, Widths, RMSE, and Pearson R
# 0.7916 4.0175422341894516 1.5016705910708557 0.8565351938770227
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.778 4.025097718572703 1.5305532834297542 0.853746519503673
# Patience is
# 0
#
#
# epoch number is 6
# Training Coverage, Widths, RMSE, and Pearson R
# 0.8104 4.045114979289535 1.4741890384050291 0.8620624623942116
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.792 4.0435209860983345 1.5029908883330918 0.8595004046739031
# Patience is
# 0
#
#
# epoch number is 7
# Training Coverage, Widths, RMSE, and Pearson R
# 0.8132 4.008934061798127 1.472121624596119 0.862643259114101
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.802 4.005484173617681 1.5004171330656897 0.8601259418767598
# Patience is
# 0
#
#
# epoch number is 8
# Training Coverage, Widths, RMSE, and Pearson R
# 0.8184 4.102548538596808 1.469673439453679 0.8629195301970768
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.807 4.095961901608378 1.4981234405475374 0.8604551994102998
# Patience is
# 0
#
#
# epoch number is 9
# Training Coverage, Widths, RMSE, and Pearson R
# 0.8244 4.155207573062026 1.468302064873198 0.8631747453452627
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.819 4.152420189739841 1.4986509218168778 0.8601281111674165
# Patience is
# 0
#
#
# epoch number is 10
# Training Coverage, Widths, RMSE, and Pearson R
# 0.8216 4.076943811207944 1.4682167318773582 0.8631935329002957
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.805 4.08210335420107 1.4975840752736784 0.8604535986715254
# Patience is
# 0
#
#
# epoch number is 11
# Training Coverage, Widths, RMSE, and Pearson R
# 0.8244 4.056261817604393 1.467330999364401 0.863370787565923
# Testing Coverage, Widths, RMSE, and Pearson R
# 0.805 4.062479781139375 1.4946392222612694 0.8609522635670175
# Patience is
# 0
#
#
# epoch number is 12

# %%
with open("..//Data//catch_overall_50_reps_c1.pickle", "wb") as f: 
    pickle.dump(catch_overall,f)

# %%
import pickle

# %%
with open("..//Data//catch_overall_50_reps_c1.pickle", "rb") as f: 
    catch_overall = pickle.load(f)

# %%
import pandas as pd

# %%
overall_df = pd.DataFrame(catch_overall).iloc[:,:7]
overall_df.mean()
# Out:
# 0    7.169837
# 1    0.884808
# 2    1.464778
# 3    7.151291
# 4    0.874200
# 5    1.518174
# 6    0.843854
# dtype: float64

# %%
overall_df.columns = ['best_train_width', 'best_coverage_train', 'best_rmse_train',
                      'best_test_width', 'best_coverage_test', 'best_rmse_test', 'best_pearson_r']

# %%
overall_df.mean()
# Out:
# best_train_width       7.169837
# best_coverage_train    0.884808
# best_rmse_train        1.464778
# best_test_width        7.151291
# best_coverage_test     0.874200
# best_rmse_test         1.518174
# best_pearson_r         0.843854
# dtype: float64
